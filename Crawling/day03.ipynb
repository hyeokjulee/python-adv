# %%
import requests
from bs4 import BeautifulSoup as bs

html = bs(requests.get("https://finance.naver.com/item/main.nhn?code=005930").text)
price = html.select('em.no_up > span.blind')
print(price[0].text)
# Out:
# 61,600

# %%
# !pip install pykrx # 주가 조회 모듈

from pykrx import stock
stock.get_market_ohlcv('20230302', '20230302', '005930')
# Out:
#                시가     고가     저가     종가      거래량          거래대금   등락률
# 날짜
# 2023-03-02  60900  61400  60800  61300  1723785  105203618100  1.16

# %%
# !pip install yfinance

import yfinance as yf
yf.download('TSLA', start='2023-03-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open      High         Low       Close   Adj Close  \
# Date
# 2023-03-01  206.210007  207.1987  198.520401  202.770004  202.770004
#
#                Volume
# Date
# 2023-03-01  147701973

# %%
import requests, json

url = "https://api.bithumb.com/public/ticker/BTC_KRW"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

strtojson = json.loads(response.text)
strtojson['data']['closing_price']
# Out:
# '31120000'

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.bithumb.com/react/"
driver.get(url)
txt = driver.page_source
html = bs(txt)

time.sleep(3)

price = html.select('strong.MarketRow_sort-real__5zeND')
print(price[0].text)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12808\3034709159.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# 31,110,000 원

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs

driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.bithumb.com/trade/order/BTC_KRW"
driver.get(url)
txt = driver.page_source
html = bs(txt)

price = html.select('h3.color_blue')
print(price[0].text)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12808\3980119960.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# 31,110,000

# %%
import requests, json

json.loads(requests.get("https://api.bithumb.com/public/ticker/BTC_KRW", headers={"accept": "application/json"}).text)['data']['closing_price']
# Out:
# '31125000'

# %%
# Bithumb API

# !pip install pybithumb # 빗썸에서 제공하는 API 설치 (최초 한번만 설치)

import pybithumb as pb
import time

pb.get_tickers() # tickers 는 종목명을 출력

pb.get_current_price('BTC') # 비트 코인 가격 조회

while True: # 비트 코인 가격 반복 조회
    print(pb.get_current_price('BTC'))
    time.sleep(3)
# Out:
# 31075000.0
# 31075000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12808\2041236942.py in <module>
#      12 while True: # 비트 코인 가격 반복 조회
#      13     print(pb.get_current_price('BTC'))
# ---> 14     time.sleep(3)
#
# KeyboardInterrupt:

# %%
# 모든 코인 가격 조회
for coin in pb.get_tickers():
    print(coin, pb.get_current_price(coin))
# Out:
# BTC 31119000.0
# ETH 2184000.0
# ETC 27920.0
# XRP 502.2
# BCH 176400.0
# QTUM 4416.0
# BTG 22440.0
# EOS 1577.0
# ICX 342.2
# TRX 91.9
# ELF 367.3
# OMG 2259.0
# KNC 1128.0
# GLM 357.4
# ZIL 41.87
# WAXP 114.0
# POWR 284.9
# LRC 478.4
# STEEM 310.4
# STRAX 811.5
# ZRX 395.0
# REP 11960.0
# SNT 39.61
# ADA 471.0
# CTXC 362.4
# BAT 400.7
# THETA 1564.0
# LOOM 78.21
# WAVES 3493.0
# LINK 9880.0
# ENJ 623.1
# VET 36.73
# MTL 1680.0
# IOST 15.44
# QKC 15.5
# ATOLO 11.45
# AMO 1.016
# BSV 54650.0
# ORBS 46.42
# TFUEL 79.7
# VALOR 309.5
# CON 13.89
# ANKR 51.12
# MIX 4.445
# CRO 104.1
# FX 274.9
# CHR 238.5
# MBL 5.16
# MXC 34.32
# FCT2 91.0
# TRV 7.6
# WOM 39.57
# SOC 4.54
# BOA 45.92
# MEV 16.55
# SXP 427.2
# COS 9.838
# EL 4.046
# BASIC 2.043
# HIVE 602.0
# XPR 2.147
# VRA 9.583
# FIT 0.8354
# EGG 9.55
# BORA 284.4
# ARPA 55.78
# CTC 650.0
# APM 24.53
# CKB 7.025
# AERGO 183.2
# CENNZ 24.63
# EVZ 18.37
# SRM 630.4
# QTCON 1.791
# UNI 8955.0
# YFI 13636000.0
# UMA 2935.0
# AAVE 108500.0
# ...

# %%
# 자세한 코인 가격 조회

print(pb.get_market_detail('BTC'))
# 시가 / 고가 / 저가 / 종가(현재가) / 거래량
# # 튜플로 리턴한다.
# Out:
# (31180000.0, 31272000.0, 30937000.0, 31013000.0, 226.23088343)

# %%
# 모든 코인의 자세한 가격 조회
for ticker in pb.get_tickers():
    print(ticker, pb.get_market_detail(ticker)) # 시가 / 고가 / 저가 / 종가(현재가) / 거래량
# Out:
# BTC (31180000.0, 31272000.0, 30937000.0, 31054000.0, 229.40658343)
# ETH (2180000.0, 2203000.0, 2169000.0, 2178000.0, 1883.36818367)
# ETC (27990.0, 28100.0, 27790.0, 27830.0, 19666.99615325)
# XRP (501.5, 506.9, 500.5, 501.5, 11083645.47815714)
# BCH (176900.0, 177400.0, 175500.0, 175600.0, 1153.42824352)
# QTUM (4433.0, 4463.0, 4377.0, 4385.0, 51691.49886297)
# BTG (22670.0, 22670.0, 22390.0, 22430.0, 2381.8312)
# EOS (1571.0, 1596.0, 1568.0, 1571.0, 356539.33512112)
# ICX (341.0, 350.3, 340.1, 342.0, 326777.52665761)
# TRX (91.97, 92.57, 91.76, 91.84, 5875214.56989)
# ELF (369.3, 372.1, 366.3, 367.7, 194117.1551)
# OMG (2250.0, 2283.0, 2249.0, 2250.0, 8847.3707)
# KNC (1137.0, 1145.0, 1120.0, 1120.0, 50786.11908359)
# GLM (359.6, 362.6, 353.2, 357.4, 109799.04299342)
# ZIL (42.09, 42.49, 41.55, 41.55, 1019269.4734)
# WAXP (116.3, 117.2, 112.5, 113.5, 1410310.32700223)
# POWR (300.5, 300.5, 284.0, 284.4, 1209315.33754074)
# LRC (479.2, 481.3, 473.9, 473.9, 42929.65499239)
# ...

# %%
# 네트워크를 이용하는 경우에는 특히 에러 즉 예외가 발생할 경우가 상당히 많다.
# 따라서 1) time.sleep() 을 이용한 시간 지연
#       2) try except 을 이용한 예외 처리가 중요하다.

try:
    for ticker in pb.get_tickers():
        print(ticker, pb.get_market_detail(ticker))
        time.sleep(0.1)
except:
    print("예외가 발생했습니다.")
# Out:
# BTC (31180000.0, 31272000.0, 30937000.0, 31082000.0, 235.89688343)
# ETH (2180000.0, 2203000.0, 2169000.0, 2181000.0, 1917.23848367)
# ETC (27990.0, 28100.0, 27790.0, 27910.0, 20049.01165325)
# XRP (501.5, 506.9, 500.5, 501.9, 11327245.14722966)
# BCH (176900.0, 177400.0, 175500.0, 175600.0, 1153.42824352)
# QTUM (4433.0, 4463.0, 4377.0, 4403.0, 52166.50636297)
# BTG (22670.0, 22670.0, 22390.0, 22430.0, 2381.8312)
# EOS (1571.0, 1596.0, 1568.0, 1574.0, 361859.50192112)
# ICX (341.0, 350.3, 340.1, 340.8, 326817.63255761)
# TRX (91.97, 92.57, 91.76, 91.95, 5988447.89339)
# ELF (369.3, 372.1, 366.3, 368.4, 198588.3869)
# OMG (2250.0, 2283.0, 2249.0, 2250.0, 9455.8982)
# KNC (1137.0, 1145.0, 1120.0, 1120.0, 50794.76368359)
# GLM (359.6, 362.6, 353.2, 357.4, 109799.04299342)
# ZIL (42.09, 42.49, 41.55, 41.55, 1026489.6901)
# WAXP (116.3, 117.2, 112.5, 113.1, 1507034.08940223)
# POWR (300.5, 300.5, 284.0, 284.4, 1210097.96094074)
# LRC (479.2, 481.3, 472.1, 474.5, 51585.04329239)
# ...

# %%
# 상승장 하락장 알람 프로그램

# 이동평균선을 사용 : 이동평균 값보다 현재가가 높다면 상승장
# 이동 평균 값보다 현재가가 낮으면 하락장

# 03/01 1000
# 03/02 1100
# 03/03 1200
# 03/04 1100
# 03/05 1000

# 03/06 1400 상승장
# 03/06 1000 하락장

# %%
# 받아온 데이터는 기본적으로 데이터프레임이다.
# 데이터 프레임에서 한개의 열 즉 Series 이다.

btc = pb.get_ohlcv("BTC")
close = btc['close']
close
# Out:
# time
# 2013-12-27 00:00:00      755000.0
# 2013-12-28 00:00:00      750000.0
# 2013-12-29 00:00:00      739000.0
# 2013-12-30 00:00:00      768000.0
# 2013-12-31 00:00:00      768000.0
#                           ...
# 2023-02-26 00:00:00    30890000.0
# 2023-02-27 00:00:00    31544000.0
# 2023-02-28 00:00:00    31081000.0
# 2023-03-01 00:00:00    31193000.0
# 2023-03-02 11:00:00    31082000.0
# Name: close, Length: 3263, dtype: float64

# %%
# 수동으로 이동평균 계산

btc = pb.get_ohlcv("BTC")
close = btc['close']

print((close[0] + close[1] + close[2] + close[3] + close[4]) / 5)
print((close[1] + close[2] + close[3] + close[4] + close[5]) / 5)
print((close[2] + close[3] + close[4] + close[5] + close[6]) / 5)
# Out:
# 756000.0
# 760400.0
# 766000.0

# %%
# 자동으로 이동평균 계산

btc = pb.get_ohlcv("BTC")
close = btc['close']

roll5 = close.rolling(5)
mean5 = roll5.mean()
print(mean5)

# 5일간의 평균을 계산하기 때문에 최초 4일은 계산값이 없이 NaN 으로 표시
# Out:
# time
# 2013-12-27 00:00:00           NaN
# 2013-12-28 00:00:00           NaN
# 2013-12-29 00:00:00           NaN
# 2013-12-30 00:00:00           NaN
# 2013-12-31 00:00:00      756000.0
#                           ...
# 2023-02-26 00:00:00    31049000.0
# 2023-02-27 00:00:00    31101400.0
# 2023-02-28 00:00:00    31052600.0
# 2023-03-01 00:00:00    31041200.0
# 2023-03-02 11:00:00    31163000.0
# Name: close, Length: 3263, dtype: float64

# %%
# 상승장 하락장 파악

btc = pb.get_ohlcv("BTC")
close = btc['close']

roll5 = close.rolling(5)
mean5 = roll5.mean()
last_mean5 = mean5[-2]

# 비트코인 현재값
price = pb.get_current_price('BTC')

# 비교
if price > last_mean5:
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %%
# 파이썬으로 브라우저에서 단추 클릭하기

from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import time

driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.starbucks.co.kr/store/store_map.do"
driver.get(url)
txt = driver.page_source
html = bs(txt)

driver.find_element(By.CSS_SELECTOR, '#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a').click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, '#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a').click()
time.sleep(1)
driver.find_element(By.CSS_SELECTOR, '#mCSB_2_container > ul > li:nth-child(1) > a').click()
time.sleep(3)

txt = driver.page_source
html = bs(txt)
shops = html.select('li.quickResultLstCon')
shops[0]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12808\542454101.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <li class="quickResultLstCon" data-code="3218" data-hlytag="null" data-index="0" data-lat="37.553376" data-long="126.918564" data-name="서교동사거리" data-storecd="1031" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서교동사거리" data-store="1031" data-yn="N">서교동사거리  </strong> <p class="result_details">서울특별시 마포구 양화로 105 (서교동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>
